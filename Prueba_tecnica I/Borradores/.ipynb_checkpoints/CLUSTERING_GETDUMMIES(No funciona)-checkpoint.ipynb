# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
import math

# %matplotlib inline

# %%
df_num = pd.read_csv('../data/numeric_data.csv')

# %%
#df = df_.drop(['ID'], axis=1)

# %%
logcolumns = ['Age',
 'Overall',
 'Potential',
 'Wage',
 'Special',
 'International Reputation',
 'Weight',
 'Crossing',
 'Finishing',
 'HeadingAccuracy',
 'ShortPassing',
 'Volleys',
 'Dribbling',
 'Curve',
 'FKAccuracy',
 'LongPassing',
 'BallControl',
 'Acceleration',
 'SprintSpeed',
 'Agility',
 'Reactions',
 'Balance',
 'ShotPower',
 'Jumping',
 'Stamina',
 'Strength',
 'LongShots',
 'Aggression',
 'Interceptions',
 'Positioning',
 'Vision',
 'Penalties',
 'Composure',
 'Marking',
 'StandingTackle',
 'SlidingTackle',
 'GKDiving',
 'GKHandling',
 'GKKicking',
 'GKPositioning',
 'GKReflexes']

# %%
df_num.loc[:, logcolumns] = np.log(df_num[logcolumns])

# %%
df_num
# Out:
#            ID       Age   Overall  Potential       Wage   Special  \
# 0      158023  3.433987  4.543295   4.543295  20.152336  7.697121
# 1       20801  3.496508  4.543295   4.543295  19.819398  7.708860
# 2      190871  3.258097  4.521789   4.532599  19.485391  7.669962
# 3      192985  3.295837  4.510860   4.521789  19.687628  7.732369
# 4      183277  3.295837  4.510860   4.510860  19.644456  7.669495
# ...       ...       ...       ...        ...        ...       ...
# 14738  238813  2.944439  3.850148   4.174387  13.815511  7.175490
# 14739  243165  2.944439  3.850148   4.143135  13.815511  7.001246
# 14740  241638  2.772589  3.850148   4.204693  13.815511  7.080868
# 14741  246268  2.833213  3.850148   4.189655  13.815511  7.113142
# 14742  246269  2.772589  3.828641   4.189655  13.815511  7.186144
#
#        International Reputation    Weight  Crossing  Finishing  ...  \
# 0                      1.609438  5.068904  4.430817   4.553877  ...
# 1                      1.609438  5.209486  4.430817   4.543295  ...
# 2                      1.609438  5.010635  4.369448   4.465908  ...
# 3                      1.386294  5.036953  4.532599   4.406719  ...
# 4                      1.386294  5.093750  4.394449   4.430817  ...
# ...                         ...       ...       ...        ...  ...
# 14738                  0.000000  4.897840  3.526361   3.637586  ...
# 14739                  0.000000  5.135798  3.135494   3.951244  ...
# 14740                  0.000000  4.997212  3.218876   3.688879  ...
# 14741                  0.000000  5.036953  3.784190   3.912023  ...
# 14742                  0.000000  5.170484  3.713572   3.526361  ...
#
#        Penalties  Composure   Marking  StandingTackle  SlidingTackle  \
# 0       4.317488   4.564348  3.496508        3.332205       3.258097
# 1       4.442651   4.553877  3.332205        3.433987       3.135494
# 2       4.394449   4.543295  3.295837        3.178054       3.496508
# 3       4.369448   4.477337  4.219508        4.060443       3.931826
# 4       4.454347   4.510860  3.526361        3.295837       3.091042
# ...          ...        ...       ...             ...            ...
# 14738   3.761200   3.806662  3.688879        3.871201       3.850148
# 14739   3.761200   3.737670  3.091042        2.708050       2.944439
# 14740   4.007333   3.713572  3.465736        2.564949       2.397895
# 14741   3.912023   3.828641  2.995732        3.218876       3.295837
# 14742   3.496508   3.761200  3.688879        3.761200       3.912023
#
#        GKDiving  GKHandling  GKKicking  GKPositioning  GKReflexes
# 0      1.791759    2.397895   2.708050       2.639057    2.079442
# 1      1.945910    2.397895   2.708050       2.639057    2.397895
# 2      2.197225    2.197225   2.708050       2.708050    2.397895
# 3      2.708050    2.564949   1.609438       2.302585    2.564949
# 4      2.397895    2.484907   1.791759       2.079442    2.079442
# ...         ...         ...        ...            ...         ...
# 14738  2.302585    2.564949   1.945910       2.079442    2.197225
# 14739  2.302585    2.197225   2.197225       1.609438    2.484907
# 14740  1.791759    1.609438   2.302585       1.791759    2.564949
# 14741  2.639057    1.791759   2.639057       2.079442    2.197225
# 14742  2.302585    2.708050   2.197225       2.484907    2.197225
#
# [14743 rows x 42 columns]

# %%
df_cat = pd.read_csv('../data/categorical_data.csv')

# %%
df_cat = df_cat.drop(['Name'], axis=1)

# %%
df_cat
# Out:
#            ID Nationality                 Club Preferred Foot       Work Rate
# 0      158023   Argentina         FC Barcelona           Left  Medium/ Medium
# 1       20801    Portugal             Juventus          Right       High/ Low
# 2      190871      Brazil  Paris Saint-Germain          Right    High/ Medium
# 3      192985     Belgium      Manchester City          Right      High/ High
# 4      183277     Belgium              Chelsea          Right    High/ Medium
# ...       ...         ...                  ...            ...             ...
# 14738  238813     England      Crewe Alexandra          Right  Medium/ Medium
# 14739  243165      Sweden       Trelleborgs FF          Right  Medium/ Medium
# 14740  241638     England     Cambridge United          Right  Medium/ Medium
# 14741  246268     England      Tranmere Rovers          Right  Medium/ Medium
# 14742  246269     England      Tranmere Rovers          Right  Medium/ Medium
#
# [14743 rows x 5 columns]

# %%
df_cat_dummies = pd.get_dummies(df_cat)

# %%
df = pd.merge(df_cat_dummies, df_num, how = 'left', on = 'ID')

# %%
fifa = df.to_numpy()

# %%
fifa
# Out:
# array([[1.58023000e+05, 0.00000000e+00, 0.00000000e+00, ...,
#         2.70805020e+00, 2.63905733e+00, 2.07944154e+00],
#        [2.08010000e+04, 0.00000000e+00, 0.00000000e+00, ...,
#         2.70805020e+00, 2.63905733e+00, 2.39789527e+00],
#        [1.90871000e+05, 0.00000000e+00, 0.00000000e+00, ...,
#         2.70805020e+00, 2.70805020e+00, 2.39789527e+00],
#        ...,
#        [2.41638000e+05, 0.00000000e+00, 0.00000000e+00, ...,
#         2.30258509e+00, 1.79175947e+00, 2.56494936e+00],
#        [2.46268000e+05, 0.00000000e+00, 0.00000000e+00, ...,
#         2.63905733e+00, 2.07944154e+00, 2.19722458e+00],
#        [2.46269000e+05, 0.00000000e+00, 0.00000000e+00, ...,
#         2.19722458e+00, 2.48490665e+00, 2.19722458e+00]])

# %%
import umap

reducer = umap.UMAP(random_state=42)
reducer.fit(fifa.data)
# Out:
# /home/javier/miniconda2/envs/entorno/lib/python3.7/site-packages/numba/typed_passes.py:293: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../miniconda2/envs/entorno/lib/python3.7/site-packages/umap/rp_tree.py", line 135:
# @numba.njit(fastmath=True, nogil=True, parallel=True)
# def euclidean_random_projection_split(data, indices, rng_state):
# ^
#
#   state.func_ir.loc))
# /home/javier/miniconda2/envs/entorno/lib/python3.7/site-packages/umap/nndescent.py:92: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../miniconda2/envs/entorno/lib/python3.7/site-packages/umap/utils.py", line 409:
# @numba.njit(parallel=True)
# def build_candidates(current_graph, n_vertices, n_neighbors, max_candidates, rng_state):
# ^
#
#   current_graph, n_vertices, n_neighbors, max_candidates, rng_state
# /home/javier/miniconda2/envs/entorno/lib/python3.7/site-packages/numba/typed_passes.py:293: NumbaPerformanceWarning:
# The keyword argument 'parallel=True' was specified but no transformation for parallel execution was possible.
#
# To find out why, try turning on parallel diagnostics, see http://numba.pydata.org/numba-doc/latest/user/parallel.html#diagnostics for help.
#
# File "../../../miniconda2/envs/entorno/lib/python3.7/site-packages/umap/nndescent.py", line 47:
#     @numba.njit(parallel=True)
#     def nn_descent(
#     ^
#
#   state.func_ir.loc))
# /home/javier/miniconda2/envs/entorno/lib/python3.7/site-packages/umap/spectral.py:229: UserWarning: Embedding a total of 14 separate connected components using meta-embedding (experimental)
#   n_components
# /home/javier/miniconda2/envs/entorno/lib/python3.7/site-packages/sklearn/manifold/_spectral_embedding.py:236: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn("Graph is not fully connected, spectral embedding"
# UMAP(a=None, angular_rp_forest=False, b=None, init='spectral',
#      learning_rate=1.0, local_connectivity=1.0, metric='euclidean',
#      metric_kwds=None, min_dist=0.1, n_components=2, n_epochs=None,
#      n_neighbors=15, negative_sample_rate=5, random_state=42,
#      repulsion_strength=1.0, set_op_mix_ratio=1.0, spread=1.0,
#      target_metric='categorical', target_metric_kwds=None,
#      target_n_neighbors=-1, target_weight=0.5, transform_queue_size=4.0,
#      transform_seed=42, verbose=False)

# %%
embedding = reducer.transform(fifa.data)

embedding
# Out:
# array([[  6.676613 ,  -7.9682674],
#        [-13.340486 ,   6.483927 ],
#        [  3.7016027,  -7.0291357],
#        ...,
#        [ 18.731516 ,   0.3919563],
#        [-12.476952 ,  -6.1851616],
#        [-12.486261 ,  -6.1765122]], dtype=float32)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(11)-0.5).set_ticks(np.arange(10))
plt.title('UMAP projection of the Digits dataset', fontsize=24);

# %% [markdown]
# **kmeans**

# %%
from sklearn.cluster import KMeans

kmeans = KMeans(n_clusters=3, random_state=42).fit(fifa.data)

kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
kmeans.predict(fifa.data)
# Out:
# array([1, 2, 1, ..., 0, 0, 0], dtype=int32)

# %%
kmeans.cluster_centers_[0]
# Out:
# array([2.31455841e+05, 4.25803704e-04, 2.34192037e-03, 2.44837130e-03,
#        1.10724147e-17, 3.19352778e-04, 3.19352778e-04, 5.80157547e-02,
#        5.32254631e-04, 1.17096019e-02, 1.58611880e-02, 3.19352778e-04,
#        3.83265468e-17, 1.06450926e-04, 1.09644454e-02, 1.06450926e-04,
#        2.23546945e-03, 1.27741111e-03, 1.70321482e-03, 1.38386204e-03,
#        1.27741111e-03, 1.91611667e-03, 2.02256760e-03, 1.80966574e-03,
#        7.45156483e-04, 1.59676389e-03, 9.58058335e-04, 1.59676389e-03,
#        1.70321482e-03, 1.59676389e-03, 1.80966574e-03, 8.51607409e-04,
#        1.38386204e-03, 2.23546945e-03, 1.49031297e-03, 1.91611667e-03,
#        1.91611667e-03, 1.70321482e-03, 1.59676389e-03, 2.44837130e-03,
#        2.23546945e-03, 1.17096019e-03, 1.59676389e-03, 1.06450926e-03,
#        1.17096019e-03, 1.17096019e-03, 1.27741111e-03, 1.38386204e-03,
#        8.51607409e-04, 1.91611667e-03, 1.49031297e-03, 1.38386204e-03,
#        1.59676389e-03, 2.02256760e-03, 5.32254631e-04, 1.70321482e-03,
#        1.49031297e-03, 1.91611667e-03, 1.17096019e-03, 1.49031297e-03,
#        1.49031297e-03, 1.70321482e-03, 1.49031297e-03, 1.17096019e-03,
#        2.45156483e-01, 7.54843517e-01, 4.86480732e-02, 4.15158612e-02,
#        1.84479455e-01, 2.34192037e-02, 1.17096019e-03, 2.58675750e-02,
#        8.80349159e-02, 4.77964658e-02, 5.39067490e-01, 3.11957094e+00,
#        4.15805055e+00, 4.26713999e+00, 1.48658358e+01, 7.37455513e+00,
#        1.38621449e-02, 5.08450870e+00, 3.89544600e+00, 3.79221829e+00,
#        3.97818191e+00, 4.08593509e+00, 3.72597686e+00, 4.04957040e+00,
#        3.81801207e+00, 3.70594555e+00, 3.94540625e+00, 4.09533013e+00,
#        4.21726854e+00, 4.21815805e+00, 4.16711495e+00, 4.07589907e+00,
#        4.18542402e+00, 4.00069324e+00, 4.15004837e+00, 4.16974112e+00,
#        4.12584145e+00, 3.81048865e+00, 3.98876614e+00, 3.75415059e+00,
#        3.91475912e+00, 3.93338297e+00, 3.87853711e+00, 4.02804098e+00,
#        3.81685179e+00, 3.80959755e+00, 3.76844635e+00, 2.29046373e+00,
#        2.29899498e+00, 2.29734971e+00, 2.29361645e+00, 2.29435087e+00])

# %%
kmeans = KMeans(n_clusters=10, random_state=42).fit(embedding)

kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=10, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=42, tol=0.0001, verbose=0)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], s=5)
plt.gca().set_aspect('equal', 'datalim')

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=kmeans.labels_, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(kmeans.n_clusters+1)-0.5).set_ticks(np.arange(kmeans.n_clusters))
plt.title('K-Means over the Digits dataset', fontsize=20);

# %% [markdown]
# ## **DBSCAN**

# %%
from sklearn.cluster import DBSCAN

clustering = DBSCAN().fit(embedding)

clustering
# Out:
# DBSCAN(algorithm='auto', eps=0.5, leaf_size=30, metric='euclidean',
#        metric_params=None, min_samples=5, n_jobs=None, p=None)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=clustering.labels_, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(len(np.unique(clustering.labels_))+1)-0.5).set_ticks(np.arange(len(np.unique(clustering.labels_))))
plt.title('DBSCAN over the Digits dataset', fontsize=24);

# %% [markdown]
# **HDBSCAN**

# %%
import hdbscan

clusterer = hdbscan.HDBSCAN()

clusterer.fit(embedding)

clusterer
# Out:
# HDBSCAN(algorithm='best', allow_single_cluster=False, alpha=1.0,
#         approx_min_span_tree=True, cluster_selection_epsilon=0.0,
#         cluster_selection_method='eom', core_dist_n_jobs=4,
#         gen_min_span_tree=False, leaf_size=40,
#         match_reference_implementation=False, memory=Memory(location=None),
#         metric='euclidean', min_cluster_size=5, min_samples=None, p=None,
#         prediction_data=False)

# %%
plt.scatter(embedding[:, 0], embedding[:, 1], c=clusterer.labels_, cmap='Spectral', s=5)
plt.gca().set_aspect('equal', 'datalim')
plt.colorbar(boundaries=np.arange(len(np.unique(clusterer.labels_)))+0.5).set_ticks(np.arange(len(np.unique(clusterer.labels_))))
plt.title('HDBSCAN over the Digits dataset', fontsize=24);
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-c6984cc837b3> in <module>
#       1 plt.scatter(embedding[:, 0], embedding[:, 1], c=clusterer.labels_, cmap='Spectral', s=5)
#       2 plt.gca().set_aspect('equal', 'datalim')
# ----> 3 plt.colorbar(boundaries=np.arange(len(np.unique(clusterer.labels_)))+0.5).set_ticks(np.arange(len(np.unique(clusterer.labels_))))
#       4 plt.title('HDBSCAN over the Digits dataset', fontsize=24);
#
# ~/miniconda2/envs/entorno/lib/python3.7/site-packages/matplotlib/colorbar.py in set_ticks(self, ticks, update_ticks)
#     637
#     638         if update_ticks:
# --> 639             self.update_ticks()
#     640         self.stale = True
#     641
#
# ~/miniconda2/envs/entorno/lib/python3.7/site-packages/matplotlib/colorbar.py in update_ticks(self)
#     612         else:
#     613             _log.debug('Using fixed locator on colorbar')
# --> 614             ticks, ticklabels, offset_string = self._ticker(locator, formatter)
#     615             long_axis.set_ticks(ticks)
#     616             long_axis.set_ticklabels(ticklabels)
#
# ~/miniconda2/envs/entorno/lib/python3.7/site-packages/matplotlib/colorbar.py in _ticker(self, locator, formatter)
#     848         formatter.set_data_interval(*intv)
#     849
# --> 850         b = np.array(locator())
#     851         if isinstance(locator, ticker.LogLocator):
#     852             eps = 1e-10
#
# ~/miniconda2/envs/entorno/lib/python3.7/site-packages/matplotlib/ticker.py in __call__(self)
#    1618
#    1619     def __call__(self):
# -> 1620         return self.tick_values(None, None)
#    1621
#    1622     def tick_values(self, vmin, vmax):
#
# ~/miniconda2/envs/entorno/lib/python3.7/site-packages/matplotlib/ticker.py in tick_values(self, vmin, vmax)
#    1638             if np.abs(ticks1).min() < np.abs(ticks).min():
#    1639                 ticks = ticks1
# -> 1640         return self.raise_if_exceeds(ticks)
#    1641
#    1642
#
# ~/miniconda2/envs/entorno/lib/python3.7/site-packages/matplotlib/ticker.py in raise_if_exceeds(self, locs)
#    1518             raise RuntimeError("Locator attempting to generate {} ticks from "
#    1519                                "{} to {}: exceeds Locator.MAXTICKS".format(
# -> 1520                                    len(locs), locs[0], locs[-1]))
#    1521         return locs
#    1522
#
# RuntimeError: Locator attempting to generate 1119 ticks from 0 to 1118: exceeds Locator.MAXTICKS
